# %% [markdown]
# # Utility notebook for extracting out confidence scores from boltz2 predictions

# %%
import os
import pandas as pd
import json
import shutil

# This script is designed to parse the results from boltz2 predictions, extract relevant data,
# and save it in a structured format for further analysis.

# Data output structure from boltz2
"""
So boltz2 outputs data in a directory structure like this:

~/boltz_results_MIPS-0051357/predictions/MIPS-0051357

in side this directory, there are multiple files , including the confidence scores per model:
confidence_MIPS-0051357_model_0.json
confidence_MIPS-0051357_model_1.json
confidence_MIPS-0051357_model_2.json
confidence_MIPS-0051357_model_3.json
confidence_MIPS-0051357_model_4.json

and the models themselves:
MIPS-0051357_model_0.cif
MIPS-0051357_model_1.cif
MIPS-0051357_model_2.cif
MIPS-0051357_model_3.cif
MIPS-0051357_model_4.cif

The confidence files are in JSON format, and look like this:
{
    "confidence_score": 0.8774623870849609,
    "ptm": 0.7683840990066528,
    "iptm": 0.8961464762687683,
    "ligand_iptm": 0.8961464762687683,
    "protein_iptm": 0.0,
    "complex_plddt": 0.8727914094924927,
    "complex_iplddt": 0.7528989315032959,
    "complex_pde": 0.8251760005950928,
    "complex_ipde": 2.783323049545288,
    "chains_ptm": {
        "0": 0.7612196803092957,
        "1": 0.945591151714325
    },
    "pair_chains_iptm": {
        "0": {
            "0": 0.7612196803092957,
            "1": 0.4030245244503021
        },
        "1": {
            "0": 0.8961464762687683,
            "1": 0.945591151714325
        }
    }
}
"""

def parse_boltz2_results(directory):
    results = []
    print(f"Scanning directory: {directory}")  # Debugging statement
    confidence_files = [f for f in os.listdir(directory) if f.startswith('confidence_') and f.endswith('.json')]
    print(f"Found confidence files: {confidence_files}")  # Debugging statement

    for conf_file in confidence_files:
        model_index = conf_file.split('_')[-1].split('.')[0]  # Extract model index from filename
        base_name = '_'.join(conf_file.split('_')[1:-2])
        confidence_data = json.load(open(os.path.join(directory, conf_file), 'r'))  # Load the JSON data

        # Find the corresponding model file dynamically based on the confidence file name
        base_name = conf_file.replace('confidence_', '').replace(f'_model_{model_index}.json', '')
        model_file = f"{base_name}_model_{model_index}.cif"
        model_path = os.path.join(directory, model_file)
        print(f"Constructed model path: {model_path}")  # Debugging statement

        if os.path.exists(model_path):
            print(f"Model file exists: {model_path}")  # Debugging statement
            results.append({
                'model_path': model_path,
                'model_index': model_index,
                'confidence_score': confidence_data['confidence_score'],
                'ptm': confidence_data['ptm'],
                'iptm': confidence_data['iptm'],
                'ligand_iptm': confidence_data['ligand_iptm'],
                'protein_iptm': confidence_data['protein_iptm'],
                'complex_plddt': confidence_data['complex_plddt'],
                'complex_iplddt': confidence_data['complex_iplddt'],
                'complex_pde': confidence_data['complex_pde'],
                'complex_ipde': confidence_data['complex_ipde'],
                'chains_ptm': confidence_data['chains_ptm'],
                'pair_chains_iptm': confidence_data['pair_chains_iptm']  
            })
        else:
            print(f"Model file does not exist: {model_path}")  # Debugging statement

    return pd.DataFrame(results)

# Function to combine the CSV results from multiple files:
def combine_csv_results(file_list):
    combined_df = pd.concat([pd.read_csv(f) for f in file_list if f.endswith('_results.csv')])
    return combined_df

folder_list = os.listdir('./')

print(f"Found folders: {folder_list}")  # Debugging statement

for folder in folder_list:
    if folder.startswith('boltz_results_'):
        # Process only folders that start with 'boltz_results_'
        # The .json files within this folder are two folders further up in the directory structure
        # so we need to adjust the path accordingly
        # For example, if the folder is 'boltz_results_MIPS-0051357', we will look for
        # 'boltz_results_MIPS-0051357/predictions/MIPS-0051357'
        # Adjust the path to point to the correct directory
        predictions_folder = os.path.join(folder, 'predictions/', folder.split('_')[2])
        if not os.path.exists(predictions_folder):
            print(f"Predictions folder does not exist: {predictions_folder}")
            continue
        else:
            print(f"working on folder: {predictions_folder}")
        print(f"Processing folder: {predictions_folder}")  # Debugging statement
        results_df = parse_boltz2_results(os.path.join('./', predictions_folder))
        # For example, to save it as a CSV file:
        results_df.to_csv(f"{folder}_results.csv", index=False)
    else:
        print(f"Skipping folder: {folder} (does not start with 'boltz_results_')")

# Combine all the CSV files into a single DataFrame

file_list = [f for f in os.listdir('./') if f.endswith('_results.csv')]

combined_df = combine_csv_results(file_list)
combined_df.to_csv('boltz_results_combined.csv', index=False)
print("Combined results saved to 'boltz_results_combined.csv'")  # Debugging statement

confidence_value = float(input(("Enter the confidence value to filter results (default is 0.9): ")))


# Filtering the DataFrame to include only rows with a confidence score greater than 0.9 
filtered_df = combined_df[combined_df['confidence_score'] > confidence_value]
filtered_df.to_csv('boltz_results_filtered.csv', index=False)
print("Filtered results saved to 'boltz_results_filtered.csv'")  # Debugging statement

# Using the filtered DataFrame to copy the corresponding .cif model files into a new directory
output_dir = 'filtered_models'
os.makedirs(output_dir, exist_ok=True)
for index, row in filtered_df.iterrows():
    model_path = row['model_path']
    if os.path.exists(model_path):
        # Copy the model file to the output directory
        os.system(f"cp {model_path} {output_dir}")
        print(f"Copied {model_path} to {output_dir}")
    else:
        print(f"Model file does not exist: {model_path}")  # Debugging statement

# remove the temporary .csv files
for file in file_list:
    if os.path.exists(file):
        os.remove(file)
        print(f"Removed temporary file: {file}")  # Debugging statement
    else:
        print(f"File does not exist: {file}")  # Debugging statement


# Copy all the .cif files from the combined results to a new directory
combined_output_dir = 'combined_models'
os.makedirs(combined_output_dir, exist_ok=True)
for file in combined_df['model_path'].unique():
    if os.path.exists(file):
        # Copy the model file to the output directory
        os.system(f"cp {file} {combined_output_dir}")
        print(f"Copied {file} to {combined_output_dir}")
    else:print(prediction_id)
        print(f"File does not exist: {file}")  # Debugging statement
# Out:
# Found folders: ['boltz_results_MIPS-0051388', 'boltz_results_MIPS-0051448', 'boltz_results_MIPS-0051542', 'boltz_results_MIPS-0052099', 'boltz_results_MIPS-0051392', 'boltz_results_MIPS-0051541', 'boltz_results_MIPS-0051449', 'boltz_results_MIPS-0051839', 'boltz_results_MIPS-0051315', 'boltz_results_MIPS-0051436', 'Series_1b_-_500_compounds.csv', 'boltz_results_MIPS-0051579', 'boltz_results_MIPS-0051841', 'boltz_results_MIPS-0051482', 'boltz_results_archive_0.9.zip', 'boltz_results_MIPS-0052114', 'boltz_results_MIPS-0051679', 'boltz_results_MIPS-0051540', 'boltz_results_MIPS-0051519', 'boltz_results_MIPS-0052048', 'boltz_results_MIPS-0051581', 'boltz_results_MIPS-0051549', 'README.md', 'boltz_results_MIPS-0051678', 
PS-0051543', 'boltz_batch_SLURM.bash', 'boltz_results_MIPS-0051362', 'boltz_results_MIPS-0051583', 'boltz_results_MIPS-0051513', 'boltz_results_MIPS-0051383', 'boltz_results_MIPS-0052105', 'boltz_results_MIPS-0052063', 'boltz_results_MIPS-0052061', 'boltz_results_MIPS-0052066', 'boltz_results_MIPS-0051614', 'boltz_results_MIPS-0051516', 'boltz_results_MIPS-0051620', 'boltz_results_MIPS-0051415', 'boltz_results_MIPS-0051384', 'boltz_results_MIPS-0052052', 'boltz_results_MIPS-0052062', ' ...
# working on folder: boltz_results_MIPS-0051388/predictions/MIPS-0051388
# Processing folder: boltz_results_MIPS-0051388/predictions/MIPS-0051388
# Scanning directory: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388
# Found confidence files: ['confidence_MIPS-0051388_model_4.json', 'confidence_MIPS-0051388_model_2.json', 'confidence_MIPS-0051388_model_3.json', 'confidence_MIPS-0051388_model_1.json', 'confidence_MIPS-0051388_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051388/predictions/MIPS-0051388/MIPS-0051388_model_0.cif
# working on folder: boltz_results_MIPS-0051448/predictions/MIPS-0051448
# Processing folder: boltz_results_MIPS-0051448/predictions/MIPS-0051448
# Scanning directory: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448
# Found confidence files: ['confidence_MIPS-0051448_model_4.json', 'confidence_MIPS-0051448_model_3.json', 'confidence_MIPS-0051448_model_1.json', 'confidence_MIPS-0051448_model_2.json', 'confidence_MIPS-0051448_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051448/predictions/MIPS-0051448/MIPS-0051448_model_0.cif
# working on folder: boltz_results_MIPS-0051542/predictions/MIPS-0051542
# Processing folder: boltz_results_MIPS-0051542/predictions/MIPS-0051542
# Scanning directory: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542
# Found confidence files: ['confidence_MIPS-0051542_model_1.json', 'confidence_MIPS-0051542_model_0.json', 'confidence_MIPS-0051542_model_4.json', 'confidence_MIPS-0051542_model_3.json', 'confidence_MIPS-0051542_model_2.json']
# Constructed model path: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051542/predictions/MIPS-0051542/MIPS-0051542_model_2.cif
# working on folder: boltz_results_MIPS-0052099/predictions/MIPS-0052099
# Processing folder: boltz_results_MIPS-0052099/predictions/MIPS-0052099
# Scanning directory: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099
# Found confidence files: ['confidence_MIPS-0052099_model_1.json', 'confidence_MIPS-0052099_model_2.json', 'confidence_MIPS-0052099_model_4.json', 'confidence_MIPS-0052099_model_3.json', 'confidence_MIPS-0052099_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_1.cif
# Model file exists: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_2.cif
# Model file exists: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_4.cif
# Model file exists: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_3.cif
# Model file exists: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_0.cif
# Model file exists: ./boltz_results_MIPS-0052099/predictions/MIPS-0052099/MIPS-0052099_model_0.cif
# working on folder: boltz_results_MIPS-0051392/predictions/MIPS-0051392
# Processing folder: boltz_results_MIPS-0051392/predictions/MIPS-0051392
# Scanning directory: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392
# Found confidence files: ['confidence_MIPS-0051392_model_4.json', 'confidence_MIPS-0051392_model_3.json', 'confidence_MIPS-0051392_model_1.json', 'confidence_MIPS-0051392_model_2.json', 'confidence_MIPS-0051392_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051392/predictions/MIPS-0051392/MIPS-0051392_model_0.cif
# working on folder: boltz_results_MIPS-0051541/predictions/MIPS-0051541
# Processing folder: boltz_results_MIPS-0051541/predictions/MIPS-0051541
# Scanning directory: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541
# Found confidence files: ['confidence_MIPS-0051541_model_2.json', 'confidence_MIPS-0051541_model_1.json', 'confidence_MIPS-0051541_model_3.json', 'confidence_MIPS-0051541_model_0.json', 'confidence_MIPS-0051541_model_4.json']
# Constructed model path: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051541/predictions/MIPS-0051541/MIPS-0051541_model_4.cif
# working on folder: boltz_results_MIPS-0051449/predictions/MIPS-0051449
# Processing folder: boltz_results_MIPS-0051449/predictions/MIPS-0051449
# Scanning directory: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449
# Found confidence files: ['confidence_MIPS-0051449_model_3.json', 'confidence_MIPS-0051449_model_4.json', 'confidence_MIPS-0051449_model_2.json', 'confidence_MIPS-0051449_model_1.json', 'confidence_MIPS-0051449_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051449/predictions/MIPS-0051449/MIPS-0051449_model_0.cif
# working on folder: boltz_results_MIPS-0051839/predictions/MIPS-0051839
# Processing folder: boltz_results_MIPS-0051839/predictions/MIPS-0051839
# Scanning directory: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839
# Found confidence files: ['confidence_MIPS-0051839_model_1.json', 'confidence_MIPS-0051839_model_0.json', 'confidence_MIPS-0051839_model_2.json', 'confidence_MIPS-0051839_model_4.json', 'confidence_MIPS-0051839_model_3.json']
# Constructed model path: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051839/predictions/MIPS-0051839/MIPS-0051839_model_3.cif
# working on folder: boltz_results_MIPS-0051315/predictions/MIPS-0051315
# Processing folder: boltz_results_MIPS-0051315/predictions/MIPS-0051315
# Scanning directory: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315
# Found confidence files: ['confidence_MIPS-0051315_model_4.json', 'confidence_MIPS-0051315_model_1.json', 'confidence_MIPS-0051315_model_0.json', 'confidence_MIPS-0051315_model_3.json', 'confidence_MIPS-0051315_model_2.json']
# Constructed model path: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051315/predictions/MIPS-0051315/MIPS-0051315_model_2.cif
# working on folder: boltz_results_MIPS-0051436/predictions/MIPS-0051436
# Processing folder: boltz_results_MIPS-0051436/predictions/MIPS-0051436
# Scanning directory: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436
# Found confidence files: ['confidence_MIPS-0051436_model_3.json', 'confidence_MIPS-0051436_model_2.json', 'confidence_MIPS-0051436_model_0.json', 'confidence_MIPS-0051436_model_4.json', 'confidence_MIPS-0051436_model_1.json']
# Constructed model path: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051436/predictions/MIPS-0051436/MIPS-0051436_model_1.cif
# Skipping folder: Series_1b_-_500_compounds.csv (does not start with 'boltz_results_')
# working on folder: boltz_results_MIPS-0051579/predictions/MIPS-0051579
# Processing folder: boltz_results_MIPS-0051579/predictions/MIPS-0051579
# Scanning directory: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579
# Found confidence files: ['confidence_MIPS-0051579_model_3.json', 'confidence_MIPS-0051579_model_0.json', 'confidence_MIPS-0051579_model_2.json', 'confidence_MIPS-0051579_model_4.json', 'confidence_MIPS-0051579_model_1.json']
# Constructed model path: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051579/predictions/MIPS-0051579/MIPS-0051579_model_1.cif
# working on folder: boltz_results_MIPS-0051841/predictions/MIPS-0051841
# Processing folder: boltz_results_MIPS-0051841/predictions/MIPS-0051841
# Scanning directory: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841
# Found confidence files: ['confidence_MIPS-0051841_model_3.json', 'confidence_MIPS-0051841_model_4.json', 'confidence_MIPS-0051841_model_1.json', 'confidence_MIPS-0051841_model_2.json', 'confidence_MIPS-0051841_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051841/predictions/MIPS-0051841/MIPS-0051841_model_0.cif
# working on folder: boltz_results_MIPS-0051482/predictions/MIPS-0051482
# Processing folder: boltz_results_MIPS-0051482/predictions/MIPS-0051482
# Scanning directory: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482
# Found confidence files: ['confidence_MIPS-0051482_model_2.json', 'confidence_MIPS-0051482_model_4.json', 'confidence_MIPS-0051482_model_3.json', 'confidence_MIPS-0051482_model_0.json', 'confidence_MIPS-0051482_model_1.json']
# Constructed model path: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051482/predictions/MIPS-0051482/MIPS-0051482_model_1.cif
# Predictions folder does not exist: boltz_results_archive_0.9.zip/predictions/archive
# working on folder: boltz_results_MIPS-0052114/predictions/MIPS-0052114
# Processing folder: boltz_results_MIPS-0052114/predictions/MIPS-0052114
# Scanning directory: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114
# Found confidence files: ['confidence_MIPS-0052114_model_2.json', 'confidence_MIPS-0052114_model_1.json', 'confidence_MIPS-0052114_model_3.json', 'confidence_MIPS-0052114_model_0.json', 'confidence_MIPS-0052114_model_4.json']
# Constructed model path: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_2.cif
# Model file exists: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_1.cif
# Model file exists: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_3.cif
# Model file exists: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_0.cif
# Model file exists: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_4.cif
# Model file exists: ./boltz_results_MIPS-0052114/predictions/MIPS-0052114/MIPS-0052114_model_4.cif
# working on folder: boltz_results_MIPS-0051679/predictions/MIPS-0051679
# Processing folder: boltz_results_MIPS-0051679/predictions/MIPS-0051679
# Scanning directory: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679
# Found confidence files: ['confidence_MIPS-0051679_model_4.json', 'confidence_MIPS-0051679_model_2.json', 'confidence_MIPS-0051679_model_0.json', 'confidence_MIPS-0051679_model_1.json', 'confidence_MIPS-0051679_model_3.json']
# Constructed model path: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051679/predictions/MIPS-0051679/MIPS-0051679_model_3.cif
# working on folder: boltz_results_MIPS-0051540/predictions/MIPS-0051540
# Processing folder: boltz_results_MIPS-0051540/predictions/MIPS-0051540
# Scanning directory: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540
# Found confidence files: ['confidence_MIPS-0051540_model_1.json', 'confidence_MIPS-0051540_model_4.json', 'confidence_MIPS-0051540_model_2.json', 'confidence_MIPS-0051540_model_0.json', 'confidence_MIPS-0051540_model_3.json']
# Constructed model path: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051540/predictions/MIPS-0051540/MIPS-0051540_model_3.cif
# working on folder: boltz_results_MIPS-0051519/predictions/MIPS-0051519
# Processing folder: boltz_results_MIPS-0051519/predictions/MIPS-0051519
# Scanning directory: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519
# Found confidence files: ['confidence_MIPS-0051519_model_3.json', 'confidence_MIPS-0051519_model_2.json', 'confidence_MIPS-0051519_model_4.json', 'confidence_MIPS-0051519_model_0.json', 'confidence_MIPS-0051519_model_1.json']
# Constructed model path: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_1.cif
# working on folder: boltz_results_MIPS-0052048/predictions/MIPS-0052048
# Processing folder: boltz_results_MIPS-0052048/predictions/MIPS-0052048
# Scanning directory: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048
# Found confidence files: ['confidence_MIPS-0052048_model_3.json', 'confidence_MIPS-0052048_model_2.json', 'confidence_MIPS-0052048_model_1.json', 'confidence_MIPS-0052048_model_0.json', 'confidence_MIPS-0052048_model_4.json']
# Constructed model path: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_3.cif
# Model file exists: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_2.cif
# Model file exists: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_1.cif
# Model file exists: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_0.cif
# Model file exists: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_4.cif
# Model file exists: ./boltz_results_MIPS-0052048/predictions/MIPS-0052048/MIPS-0052048_model_4.cif
# working on folder: boltz_results_MIPS-0051581/predictions/MIPS-0051581
# Processing folder: boltz_results_MIPS-0051581/predictions/MIPS-0051581
# Scanning directory: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581
# Found confidence files: ['confidence_MIPS-0051581_model_2.json', 'confidence_MIPS-0051581_model_4.json', 'confidence_MIPS-0051581_model_3.json', 'confidence_MIPS-0051581_model_1.json', 'confidence_MIPS-0051581_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051581/predictions/MIPS-0051581/MIPS-0051581_model_0.cif
# working on folder: boltz_results_MIPS-0051549/predictions/MIPS-0051549
# Processing folder: boltz_results_MIPS-0051549/predictions/MIPS-0051549
# Scanning directory: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549
# Found confidence files: ['confidence_MIPS-0051549_model_1.json', 'confidence_MIPS-0051549_model_3.json', 'confidence_MIPS-0051549_model_2.json', 'confidence_MIPS-0051549_model_4.json', 'confidence_MIPS-0051549_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051549/predictions/MIPS-0051549/MIPS-0051549_model_0.cif
# Skipping folder: README.md (does not start with 'boltz_results_')
# working on folder: boltz_results_MIPS-0051678/predictions/MIPS-0051678
# Processing folder: boltz_results_MIPS-0051678/predictions/MIPS-0051678
# Scanning directory: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678
# Found confidence files: ['confidence_MIPS-0051678_model_2.json', 'confidence_MIPS-0051678_model_1.json', 'confidence_MIPS-0051678_model_4.json', 'confidence_MIPS-0051678_model_0.json', 'confidence_MIPS-0051678_model_3.json']
# Constructed model path: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051678/predictions/MIPS-0051678/MIPS-0051678_model_3.cif
# working on folder: boltz_results_MIPS-0051484/predictions/MIPS-0051484
# Processing folder: boltz_results_MIPS-0051484/predictions/MIPS-0051484
# Scanning directory: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484
# Found confidence files: ['confidence_MIPS-0051484_model_1.json', 'confidence_MIPS-0051484_model_2.json', 'confidence_MIPS-0051484_model_3.json', 'confidence_MIPS-0051484_model_4.json', 'confidence_MIPS-0051484_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051484/predictions/MIPS-0051484/MIPS-0051484_model_0.cif
# working on folder: boltz_results_MIPS-0051675/predictions/MIPS-0051675
# Processing folder: boltz_results_MIPS-0051675/predictions/MIPS-0051675
# Scanning directory: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675
# Found confidence files: ['confidence_MIPS-0051675_model_1.json', 'confidence_MIPS-0051675_model_3.json', 'confidence_MIPS-0051675_model_0.json', 'confidence_MIPS-0051675_model_4.json', 'confidence_MIPS-0051675_model_2.json']
# Constructed model path: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051675/predictions/MIPS-0051675/MIPS-0051675_model_2.cif
# Skipping folder: Series_1a_-_134_compounds.csv (does not start with 'boltz_results_')
# working on folder: boltz_results_MIPS-0052059/predictions/MIPS-0052059
# Processing folder: boltz_results_MIPS-0052059/predictions/MIPS-0052059
# Scanning directory: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059
# Found confidence files: ['confidence_MIPS-0052059_model_1.json', 'confidence_MIPS-0052059_model_0.json', 'confidence_MIPS-0052059_model_3.json', 'confidence_MIPS-0052059_model_4.json', 'confidence_MIPS-0052059_model_2.json']
# Constructed model path: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_1.cif
# Model file exists: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_0.cif
# Model file exists: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_3.cif
# Model file exists: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_4.cif
# Model file exists: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_2.cif
# Model file exists: ./boltz_results_MIPS-0052059/predictions/MIPS-0052059/MIPS-0052059_model_2.cif
# working on folder: boltz_results_MIPS-0051546/predictions/MIPS-0051546
# Processing folder: boltz_results_MIPS-0051546/predictions/MIPS-0051546
# Scanning directory: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546
# Found confidence files: ['confidence_MIPS-0051546_model_0.json', 'confidence_MIPS-0051546_model_1.json', 'confidence_MIPS-0051546_model_4.json', 'confidence_MIPS-0051546_model_3.json', 'confidence_MIPS-0051546_model_2.json']
# Constructed model path: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051546/predictions/MIPS-0051546/MIPS-0051546_model_2.cif
# Skipping folder: GenerateTemplate_YAML.ipynb (does not start with 'boltz_results_')
# working on folder: boltz_results_MIPS-0052121/predictions/MIPS-0052121
# Processing folder: boltz_results_MIPS-0052121/predictions/MIPS-0052121
# Scanning directory: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121
# Found confidence files: ['confidence_MIPS-0052121_model_3.json', 'confidence_MIPS-0052121_model_0.json', 'confidence_MIPS-0052121_model_4.json', 'confidence_MIPS-0052121_model_1.json', 'confidence_MIPS-0052121_model_2.json']
# Constructed model path: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_3.cif
# Model file exists: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_0.cif
# Model file exists: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_4.cif
# Model file exists: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_1.cif
# Model file exists: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_2.cif
# Model file exists: ./boltz_results_MIPS-0052121/predictions/MIPS-0052121/MIPS-0052121_model_2.cif
# working on folder: boltz_results_MIPS-0051290/predictions/MIPS-0051290
# Processing folder: boltz_results_MIPS-0051290/predictions/MIPS-0051290
# Scanning directory: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290
# Found confidence files: ['confidence_MIPS-0051290_model_0.json', 'confidence_MIPS-0051290_model_3.json', 'confidence_MIPS-0051290_model_4.json', 'confidence_MIPS-0051290_model_1.json', 'confidence_MIPS-0051290_model_2.json']
# Constructed model path: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051290/predictions/MIPS-0051290/MIPS-0051290_model_2.cif
# working on folder: boltz_results_MIPS-0052057/predictions/MIPS-0052057
# Processing folder: boltz_results_MIPS-0052057/predictions/MIPS-0052057
# Scanning directory: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057
# Found confidence files: ['confidence_MIPS-0052057_model_0.json', 'confidence_MIPS-0052057_model_3.json', 'confidence_MIPS-0052057_model_2.json', 'confidence_MIPS-0052057_model_4.json', 'confidence_MIPS-0052057_model_1.json']
# Constructed model path: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_0.cif
# Model file exists: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_3.cif
# Model file exists: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_2.cif
# Model file exists: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_4.cif
# Model file exists: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_1.cif
# Model file exists: ./boltz_results_MIPS-0052057/predictions/MIPS-0052057/MIPS-0052057_model_1.cif
# working on folder: boltz_results_MIPS-0052190/predictions/MIPS-0052190
# Processing folder: boltz_results_MIPS-0052190/predictions/MIPS-0052190
# Scanning directory: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190
# Found confidence files: ['confidence_MIPS-0052190_model_1.json', 'confidence_MIPS-0052190_model_0.json', 'confidence_MIPS-0052190_model_2.json', 'confidence_MIPS-0052190_model_4.json', 'confidence_MIPS-0052190_model_3.json']
# Constructed model path: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_1.cif
# Model file exists: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_0.cif
# Model file exists: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_0.cif
# Constructed model path: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_2.cif
# Model file exists: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_4.cif
# Model file exists: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_3.cif
# Model file exists: ./boltz_results_MIPS-0052190/predictions/MIPS-0052190/MIPS-0052190_model_3.cif
# working on folder: boltz_results_MIPS-0051360/predictions/MIPS-0051360
# Processing folder: boltz_results_MIPS-0051360/predictions/MIPS-0051360
# Scanning directory: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360
# Found confidence files: ['confidence_MIPS-0051360_model_2.json', 'confidence_MIPS-0051360_model_4.json', 'confidence_MIPS-0051360_model_3.json', 'confidence_MIPS-0051360_model_1.json', 'confidence_MIPS-0051360_model_0.json']
# Constructed model path: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_2.cif
# Model file exists: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_2.cif
# Constructed model path: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_4.cif
# Model file exists: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_4.cif
# Constructed model path: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_3.cif
# Model file exists: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_3.cif
# Constructed model path: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_1.cif
# Model file exists: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_1.cif
# Constructed model path: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_0.cif
# Model file exists: ./boltz_results_MIPS-0051360/predictions/MIPS-0051360/MIPS-0051360_model_0.cif
# working on folder: boltz_results_MIPS-0052106/predictions/MIPS-0052106
# Processing folder: boltz_results_MIPS-0052106/predictions/MIPS-0052106
# ...
# Copied ./boltz_results_MIPS-0051417/predictions/MIPS-0051417/MIPS-0051417_model_4.cif to combined_models
# Copied ./boltz_results_MIPS-0051417/predictions/MIPS-0051417/MIPS-0051417_model_0.cif to combined_models
# Copied ./boltz_results_MIPS-0051582/predictions/MIPS-0051582/MIPS-0051582_model_3.cif to combined_models
# Copied ./boltz_results_MIPS-0051582/predictions/MIPS-0051582/MIPS-0051582_model_2.cif to combined_models
# Copied ./boltz_results_MIPS-0051582/predictions/MIPS-0051582/MIPS-0051582_model_0.cif to combined_models
# Copied ./boltz_results_MIPS-0051582/predictions/MIPS-0051582/MIPS-0051582_model_1.cif to combined_models
# Copied ./boltz_results_MIPS-0051582/predictions/MIPS-0051582/MIPS-0051582_model_4.cif to combined_models
# Copied ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_3.cif to combined_models
# Copied ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_2.cif to combined_models
# Copied ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_4.cif to combined_models
# Copied ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_0.cif to combined_models
# Copied ./boltz_results_MIPS-0051519/predictions/MIPS-0051519/MIPS-0051519_model_1.cif to combined_models
# Copied ./boltz_results_MIPS-0051547/predictions/MIPS-0051547/MIPS-0051547_model_4.cif to combined_models
# Copied ./boltz_results_MIPS-0051547/predictions/MIPS-0051547/MIPS-0051547_model_2.cif to combined_models
# Copied ./boltz_results_MIPS-0051547/predictions/MIPS-0051547/MIPS-0051547_model_3.cif to combined_models
# Copied ./boltz_results_MIPS-0051547/predictions/MIPS-0051547/MIPS-0051547_model_1.cif to combined_models
# Copied ./boltz_results_MIPS-0051547/predictions/MIPS-0051547/MIPS-0051547_model_0.cif to combined_models
# Copied ./boltz_results_MIPS-0051682/predictions/MIPS-0051682/MIPS-0051682_model_0.cif to combined_models
# Copied ./boltz_results_MIPS-0051682/predictions/MIPS-0051682/MIPS-0051682_model_1.cif to combined_models
# Copied ./boltz_results_MIPS-0051682/predictions/MIPS-0051682/MIPS-0051682_model_4.cif to combined_models
# Copied ./boltz_results_MIPS-0
model_2.cif to combined_models
# Copied ./boltz_results_MIPS-0052065/predictions/MIPS-0052065/MIPS-0052065_model_3.cif to combined_models
# Copied ./boltz_results_MIPS-0052065/predictions/MIPS-0052065/MIPS-0052065_model_2.cif to combined_models
# Copied ./boltz_results_MIPS-0052065/predictions/MIPS-0052065/MIPS-0052065_model_0.cif to combined_models
# Copied ./boltz_results_MIPS-0052065/predictions/MIPS-0052065/MIPS-0052065_model_1.cif to combined_models
# Copied ./boltz_results_MIPS-0052065/predictions/MIPS-0052065/MIPS-0052065_model_4.cif to combined_models
# Results Filtered and Collated comrade

# %%
# Utility to take the top confidence results for each prediction and match add them to a .csv file which has pharmacology data

pharm_data1 = pd.read_csv('Series_1a_-_134_compounds.csv')
pharm_data2 = pd.read_csv('Series_1b_-_500_compounds.csv')


top_confidence_results_by_prediction = {}
for index, row in combined_df.iterrows():
    model_index = row['model_index']
    model_path = row['model_path']
    confidence_score = row['confidence_score']
    ipTM = row['iptm']
    plddt_score = row['complex_plddt']
    
    # Extract the prediction ID from the model path
    prediction_id = os.path.basename(model_path).split('_')[0]
    
    if prediction_id not in top_confidence_results_by_prediction:
        top_confidence_results_by_prediction[prediction_id] = {
            'model_index': model_index,
            'model_path': model_path,
            'confidence_score': confidence_score,
            'iptm': ipTM,
            'plddt_score': plddt_score
        }
    else:
        # If the prediction already exists, compare confidence scores
        if confidence_score > top_confidence_results_by_prediction[prediction_id]['confidence_score']:
            top_confidence_results_by_prediction[prediction_id] = {
                'model_index': model_index,
                'model_path': model_path,
                'confidence_score': confidence_score,
                'iptm': ipTM,
                'plddt_score': plddt_score
            }

# Convert the dictionary to a DataFrame
top_confidence_df = pd.DataFrame.from_dict(top_confidence_results_by_prediction, orient='index').reset_index()
top_confidence_df.rename(columns={'index': 'prediction_id'}, inplace=True)

save_path = 'top_confidence_results_all_models.csv'
top_confidence_df.to_csv(save_path, index=False)

# Now need to merge this with the pharmacology data: Note that the pharmachology data has the prediction_id named 'Molecule Name'ArithmeticError
# First merge the two pharmacology datasets
pharm_data = pd.concat([pharm_data1, pharm_data2], ignore_index=True)

# Merge the top confidence results with the pharmacology data
merged_df = pd.merge(top_confidence_df, pharm_data, left_on='prediction_id', right_on='Molecule Name', how='left')
# Save the merged DataFrame to a CSV file
merged_save_path = 'top_confidence_results_with_pharm_data.csv'
merged_df.to_csv(merged_save_path, index=False)
print(f"Top confidence results with pharmacology data saved to {merged_save_path}")  #
# Out:
# Top confidence results with pharmacology data saved to top_confidence_results_with_pharm_data.csv

# %%
# Create ZIP archive of the important results for sharing
# Path to the existing archive
archive_name = f'boltz_results_archive_{confidence_value}'

# Temporary directory to extract the archive
temp_dir = 'temp_archive'

# Copy the .csv files to the temporary directory
os.makedirs(temp_dir, exist_ok=True)
shutil.copy('boltz_results_combined.csv', temp_dir)
shutil.copy('boltz_results_filtered.csv', temp_dir)
shutil.copy('top_confidence_results_all_models.csv', temp_dir)
shutil.copy('top_confidence_results_with_pharm_data.csv', temp_dir)

# Copy the filtered_models directory to the temporary directory
filtered_models_path = os.path.join(temp_dir, 'filtered_models')
shutil.copytree('filtered_models', filtered_models_path, dirs_exist_ok=True)

# Copy the combined_models directory to the temporary directory
combined_models_path = os.path.join(temp_dir, 'combined_models')
shutil.copytree('combined_models', combined_models_path, dirs_exist_ok=True)

# Create the archive with the updated contents
shutil.make_archive(archive_name, 'zip', temp_dir)

# Clean up the temporary directory
shutil.rmtree(temp_dir)


print("Results Filtered and Collated comrade")
